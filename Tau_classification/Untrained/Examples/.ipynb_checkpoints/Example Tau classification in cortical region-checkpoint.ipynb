# %% [markdown]
# ## Example script: training tau classifier for cortical regions

# %% [markdown]
# **Read in relevant files**

# %%
import sys
sys.path.insert(0,
                '/Users/tanrada/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/')

from base import *
from constants import *
from tau_classification import *

# %% [markdown]
# ### Data preparation

# %% [markdown]
# **Screening classifier**

# %%
path = "/Users/tanrada/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Training_data/screening_classifier/"
filename = "training.txt"

# Create tau database object 
s_data = TauDataBase(path = path,
                        filename = filename) 

# Prepping data to train screening classifier
s_data.classifier1_prep()

# Check data
print(s_data.c1_data['Class'].value_counts())
print(s_data.c1_X_train.shape)
# Out:
# Tau        10185
# Non_tau     9963
# Name: Class, dtype: int64
# (20148, 54)

# %% [markdown]
# **Tau classifier for cortical regions**

# %%
path = "/Users/tanrada/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Training_data/cortical_regions/"
filename = "training.txt"

# Create tau database object 
cortical_data = TauDataBase(path = path,
                        filename = filename) 

# Prepping data to train tau classifier for cortical regions
cortical_data.classifier2_prep()

# Check data
print(cortical_data.c2_data['Class'].value_counts())
print(cortical_data.c2_X_train.shape)
# Out:
# Others    2837
# CB         497
# TA         303
# NFT        147
# Name: Class, dtype: int64
# (3784, 54)

# %% [markdown]
# ### Initialising & training the classifiers

# %% [markdown]
# **Screening classifier**

# %%
screening_model = ScreeningClassifier(screening_classifier_hyperparams)
screening_model.pipeline
# Out:
# Pipeline(steps=[('normalizer', MinMaxScaler()),
#                 ('selector',
#                  RFE(estimator=RandomForestClassifier(random_state=42),
#                      n_features_to_select=44)),
#                 ('clf',
#                  BalancedRandomForestClassifier(class_weight='balanced',
#                                                 max_features=1,
#                                                 max_samples=0.75,
#                                                 min_samples_leaf=2,
#                                                 n_estimators=300,
#                                                 random_state=42,
#                                                 sampling_strategy='not '
#                                                                   'majority'))])

# %%
# Training 
screening_model.train(s_data.c1_X_train,
                     s_data.c1_Y_train)

# %%
screening_model.f_importance.head()
# Out:
#                                              features  importance
# 20                   ROI: 0.25 µm per pixel: DAB: Max    0.053625
# 16  ROI: 0.25 µm per pixel: DAB: Haralick Sum aver...    0.048330
# 26                ROI: 0.25 µm per pixel: Green: Mean    0.041939
# 21                  ROI: 0.25 µm per pixel: DAB: Mean    0.041595
# 35                  ROI: 0.25 µm per pixel: Red: Mean    0.040228

# %% [markdown]
# **Tau classifier for cortical regions**

# %%
cortical_model = TauClassifier(cortical_classifier_hyperparams)
cortical_model.pipeline
# Out:
# Pipeline(steps=[('normalizer', MinMaxScaler()),
#                 ('selector',
#                  RFE(estimator=RandomForestClassifier(random_state=42),
#                      n_features_to_select=34)),
#                 ('clf',
#                  BalancedRandomForestClassifier(class_weight='balanced',
#                                                 max_depth=15, max_features=0.6,
#                                                 max_samples=0.75,
#                                                 min_samples_leaf=2,
#                                                 n_estimators=500,
#                                                 random_state=42,
#                                                 sampling_strategy='not '
#                                                                   'majority'))])

# %%
# Training 
cortical_model.train(cortical_data.c2_X_train,
                     cortical_data.c2_Y_train)

# %%
cortical_model.best_parameters
# Out:
# {0: (0.2631443106950739,
#   0.9341809886119208,
#   0.9296717536071032,
#   0.9397142857142857),
#  1: (0.5470399932259464,
#   0.9563666419478434,
#   0.9506372549019607,
#   0.9661904761904762),
#  2: (0.6309520256218469,
#   0.9922822725611444,
#   0.9895815269468227,
#   0.9950654456775991),
#  3: (0.44842729381540636,
#   0.9388149165443382,
#   0.9216810613134141,
#   0.9607526881720432)}

# %%
cortical_model.f_importance.head()
# Out:
#                                features  importance
# 0                             Area µm^2    0.261150
# 4                       Min diameter µm    0.193786
# 2                             Length µm    0.054853
# 16  ROI: 0.25 µm per pixel: DAB: Median    0.052382
# 5    ROI: 0.25 µm per pixel: Blue: Mean    0.051438

# %% [markdown]
# ### Putting them together: tau classification pipeline for novel *cortical* slides

# %%
novel_path = '/Users/tanrada/OneDrive - University of Cambridge/Attachments/Jan2023/Detections/cortical/'
novel_filename = 'noartefact_files.txt'
prediction_path = "/Users/tanrada/OneDrive - University of Cambridge/Attachments/Jan2023/Predictions_new/Cortical/"

# %% [markdown]
# **Reading in files**

# %%
with open(novel_path + novel_filename) as f:
    mylist = f.read().splitlines()

print("Read in: ", len(mylist), "files")
# Out:
# Read in:  160 files

# %% [markdown]
# #### Tau classification

# %%
n_total = len(mylist)
faulty_file = []
for i in range(0, n_total):

    # Read in novel slide
    print("FILE", mylist[i], "Number: ", i + 1, "/", n_total)
    print("---------------STEP1: Read in data file -------------------")
    dat_file = mylist[i]

    dat_ = pd.read_csv(novel_path + dat_file, sep="\t")
    # Changing column names
    # since these names tend to be inconsistent causing problems
    dat_.columns.values[5] = "Centroid_X"
    dat_.columns.values[6] = "Centroid_Y"

    # Fixing order of the columns
    ordered = dat_[extracted_features]

    dat = ordered[ordered["Class"] == "Unlabelled"]  # only unlabelled cells
    print("Read in data file:", dat_file)
    print("Data shape is:", dat.shape)

    # Classifier 1: separating Non-tau from Tau
    print(
        "---------------STEP2: Separating Non-tau from Tau -------------------"
    )
    # 1) Remove NA cells
    dat = dat.dropna()

    predicted1_slide = dat.copy()

    # 2) Dropping extra info features
    X_unlabelled = dat.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"]
    )
    # 3) Predictions
    screening_model.predict(X_unlabelled)
    predicted1_slide["Class"] = screening_model.prediction
    print(predicted1_slide["Class"].value_counts())

    # Classifier 2: tau hallmark classification
    print(
        "---------------STEP3: Tau hallmark classification -------------------"
    )
    # Select out 'tau' portion only (ignoring non-tau & ambiguous cells )
    tau_portion = predicted1_slide[predicted1_slide["Class"] == "Tau"]
    if tau_portion.shape[0] == 0:
        print("There is no tau on this slide!")
        faulty_file.append(dat["Image"][0] + " No tau on the slide")
        continue
    tau_portion_X = tau_portion.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"])
    predicted2_slide = tau_portion.copy()
    # Separates out detections that are not tau
    non_tau_portion = predicted1_slide[predicted1_slide["Class"] != "Tau"]

    # Make predictions on Tau objects
    cortical_model.predict(tau_portion_X)
    predicted2_slide["Class"] = cortical_model.prediction
    print(predicted2_slide["Class"].value_counts())

    # Extracting data out
    print("---------------STEP4: Data extraction & export -------------------")

    # 1) Combining predicted cells & excluded cells (prior to prediction)
    total_pred = pd.concat([non_tau_portion,
                            predicted2_slide])
    print("No loss of cells? ",
          predicted1_slide.shape[0] == total_pred.shape[0])

    output_visualise = total_pred[["Image",
                                   "Class",
                                   "Centroid_X",
                                   "Centroid_Y",
                                   "Area µm^2"]]
    path_ = (
            prediction_path +
            output_visualise.iloc[0, 0] +
            "_predictions.txt"
            )
    output_visualise.to_csv(path_, sep="\t", index=False)

    print("Exported prediction of : ", dat_file)
    print("---------------------------------------------------")
print("Well done, no error!")
# Out:
# FILE 703472.svs Detections.txt Number:  1 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703472.svs Detections.txt
# Data shape is: (80333, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    78610
# Tau         1723
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1164
# CB            456
# NFT            56
# Ambiguous      33
# TA             14
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703472.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703473.svs Detections.txt Number:  2 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703473.svs Detections.txt
# Data shape is: (82112, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    75982
# Tau         6130
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       4014
# CB           1704
# NFT           221
# Ambiguous     146
# TA             45
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703473.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703482.svs Detections.txt Number:  3 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703482.svs Detections.txt
# Data shape is: (6653, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    5147
# Tau        1506
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1156
# CB            281
# Ambiguous      30
# TA             25
# NFT            14
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703482.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703484.svs Detections.txt Number:  4 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703484.svs Detections.txt
# Data shape is: (12661, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    10984
# Tau         1677
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1265
# CB            323
# Ambiguous      47
# NFT            28
# TA             14
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703484.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703485.svs Detections.txt Number:  5 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703485.svs Detections.txt
# Data shape is: (4932, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    3166
# Tau        1766
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1436
# CB            223
# NFT            61
# Ambiguous      29
# TA             17
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703485.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703516.svs Detections.txt Number:  6 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703516.svs Detections.txt
# Data shape is: (7348, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    6364
# Tau         984
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       784
# CB           177
# Ambiguous     11
# TA            10
# NFT            2
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703516.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703519.svs Detections.txt Number:  7 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703519.svs Detections.txt
# Data shape is: (15256, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    13654
# Tau         1602
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1257
# CB            274
# Ambiguous      36
# TA             24
# NFT            11
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703519.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703520.svs Detections.txt Number:  8 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703520.svs Detections.txt
# Data shape is: (14423, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    13655
# Tau          768
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       638
# CB            86
# TA            26
# Ambiguous     18
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703520.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 703521.svs Detections.txt Number:  9 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703521.svs Detections.txt
# Data shape is: (18261, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    17868
# Tau          393
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       372
# CB            13
# Ambiguous      6
# TA             1
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  703521.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721698.svs Detections.txt Number:  10 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721698.svs Detections.txt
# Data shape is: (17513, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16109
# Tau         1404
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1040
# CB            249
# NFT            52
# TA             32
# Ambiguous      31
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721698.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721699.svs Detections.txt Number:  11 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721699.svs Detections.txt
# Data shape is: (33918, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    30792
# Tau         3126
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2199
# CB            764
# Ambiguous      73
# TA             48
# NFT            42
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721699.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721700.svs Detections.txt Number:  12 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721700.svs Detections.txt
# Data shape is: (25934, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    17139
# Tau         8795
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6609
# CB           1454
# TA            303
# NFT           249
# Ambiguous     180
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721700.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721701.svs Detections.txt Number:  13 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721701.svs Detections.txt
# Data shape is: (41634, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    36424
# Tau         5210
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       3940
# CB            957
# NFT           141
# Ambiguous     113
# TA             59
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721701.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721702.svs Detections.txt Number:  14 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721702.svs Detections.txt
# Data shape is: (21996, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    20529
# Tau         1467
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1114
# CB            216
# NFT            62
# Ambiguous      42
# TA             33
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721702.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721703.svs Detections.txt Number:  15 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721703.svs Detections.txt
# Data shape is: (12243, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    11586
# Tau          657
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       558
# CB            75
# Ambiguous     12
# TA             9
# NFT            3
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721703.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721704.svs Detections.txt Number:  16 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721704.svs Detections.txt
# Data shape is: (37106, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    36281
# Tau          824
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       717
# CB            60
# NFT           28
# Ambiguous     10
# TA             9
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721704.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721705.svs Detections.txt Number:  17 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721705.svs Detections.txt
# Data shape is: (7527, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    7307
# Tau         220
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       146
# CB            43
# NFT           22
# Ambiguous      7
# TA             2
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721705.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721731.svs Detections.txt Number:  18 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721731.svs Detections.txt
# Data shape is: (33175, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    27542
# Tau         5633
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       4509
# CB            813
# TA            135
# Ambiguous     111
# NFT            65
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721731.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721733.svs Detections.txt Number:  19 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721733.svs Detections.txt
# Data shape is: (47693, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    37284
# Tau        10409
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       8092
# CB           1608
# TA            400
# Ambiguous     229
# NFT            80
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721733.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721734.svs Detections.txt Number:  20 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721734.svs Detections.txt
# Data shape is: (30680, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    21627
# Tau         9053
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       7036
# CB           1446
# TA            219
# Ambiguous     206
# NFT           146
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721734.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721735.svs Detections.txt Number:  21 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721735.svs Detections.txt
# Data shape is: (23375, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    15906
# Tau         7469
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6037
# CB            944
# TA            244
# Ambiguous     147
# NFT            97
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721735.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721770.svs Detections.txt Number:  22 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721770.svs Detections.txt
# Data shape is: (15795, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    14212
# Tau         1583
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1306
# CB            171
# TA             70
# Ambiguous      28
# NFT             8
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721770.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721771.svs Detections.txt Number:  23 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721771.svs Detections.txt
# Data shape is: (43212, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    41850
# Tau         1361
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1035
# CB            204
# Ambiguous      46
# NFT            38
# TA             38
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721771.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721772.svs Detections.txt Number:  24 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721772.svs Detections.txt
# Data shape is: (45323, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    36085
# Tau         9238
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       7676
# CB           1097
# Ambiguous     203
# TA            150
# NFT           112
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721772.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721851.svs Detections.txt Number:  25 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721851.svs Detections.txt
# Data shape is: (57422, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    56188
# Tau         1234
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       849
# CB           320
# NFT           30
# Ambiguous     27
# TA             8
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721851.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721852.svs Detections.txt Number:  26 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721852.svs Detections.txt
# Data shape is: (45865, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    45172
# Tau          693
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       535
# CB           116
# Ambiguous     22
# NFT           14
# TA             6
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721852.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721853.svs Detections.txt Number:  27 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721853.svs Detections.txt
# Data shape is: (63494, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    61447
# Tau         2047
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1501
# CB            429
# NFT            66
# Ambiguous      33
# TA             18
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721853.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721855.svs Detections.txt Number:  28 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721855.svs Detections.txt
# Data shape is: (46959, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    46360
# Tau          599
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       441
# CB           134
# Ambiguous     15
# NFT            6
# TA             3
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721855.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721856.svs Detections.txt Number:  29 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721856.svs Detections.txt
# Data shape is: (90374, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    78841
# Tau        11533
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6982
# CB           3535
# NFT           556
# Ambiguous     314
# TA            146
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721856.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 721863.svs Detections.txt Number:  30 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721863.svs Detections.txt
# Data shape is: (23577, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    20552
# Tau         3025
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2310
# CB            408
# NFT           157
# Ambiguous      91
# TA             59
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  721863.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 722215.svs Detections.txt Number:  31 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 722215.svs Detections.txt
# Data shape is: (3515, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Tau        3027
# Non_tau     488
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2446
# CB            411
# Ambiguous      77
# NFT            48
# TA             45
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  722215.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747283.svs Detections.txt Number:  32 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747283.svs Detections.txt
# Data shape is: (7074, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    4556
# Tau        2518
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2273
# TA             92
# CB             91
# Ambiguous      48
# NFT            14
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747283.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747311.svs Detections.txt Number:  33 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747311.svs Detections.txt
# Data shape is: (21160, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    12665
# Tau         8495
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6933
# TA            540
# Ambiguous     447
# CB            357
# NFT           218
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747311.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747313.svs Detections.txt Number:  34 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747313.svs Detections.txt
# Data shape is: (30026, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    20726
# Tau         9300
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       7521
# CB            638
# TA            498
# Ambiguous     445
# NFT           198
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747313.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747316.svs Detections.txt Number:  35 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747316.svs Detections.txt
# Data shape is: (36440, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    18737
# Tau        17703
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       13821
# CB            2248
# TA             860
# NFT            444
# Ambiguous      330
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747316.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747317.svs Detections.txt Number:  36 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747317.svs Detections.txt
# Data shape is: (45386, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    40760
# Tau         4626
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       3494
# CB            682
# TA            249
# Ambiguous     121
# NFT            80
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747317.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747320.svs Detections.txt Number:  37 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747320.svs Detections.txt
# Data shape is: (42119, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    39193
# Tau         2926
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2137
# CB            569
# TA            104
# Ambiguous      73
# NFT            43
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747320.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747322.svs Detections.txt Number:  38 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747322.svs Detections.txt
# Data shape is: (31423, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    25833
# Tau         5590
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       4600
# TA            424
# CB            367
# Ambiguous     139
# NFT            60
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747322.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747323.svs Detections.txt Number:  39 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747323.svs Detections.txt
# Data shape is: (43766, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    43233
# Tau          533
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       489
# CB            29
# Ambiguous     11
# NFT            3
# TA             1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747323.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747324.svs Detections.txt Number:  40 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747324.svs Detections.txt
# Data shape is: (1540, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    1059
# Tau         481
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       446
# CB            17
# TA             9
# Ambiguous      6
# NFT            3
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747324.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747329.svs Detections.txt Number:  41 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747329.svs Detections.txt
# Data shape is: (12299, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    9036
# Tau        3263
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2719
# CB            338
# TA             83
# Ambiguous      69
# NFT            54
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747329.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747330.svs Detections.txt Number:  42 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747330.svs Detections.txt
# Data shape is: (8911, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    7978
# Tau         933
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       691
# CB           161
# NFT           46
# Ambiguous     20
# TA            15
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747330.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747331.svs Detections.txt Number:  43 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747331.svs Detections.txt
# Data shape is: (13576, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    10507
# Tau         3069
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2370
# CB            418
# NFT           111
# Ambiguous      89
# TA             81
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747331.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747338.svs Detections.txt Number:  44 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747338.svs Detections.txt
# Data shape is: (27988, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    21773
# Tau         6215
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       5060
# CB            713
# TA            189
# NFT           130
# Ambiguous     123
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747338.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747364.svs Detections.txt Number:  45 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747364.svs Detections.txt
# Data shape is: (19562, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    18438
# Tau         1124
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1032
# CB             56
# Ambiguous      17
# TA             17
# NFT             2
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747364.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747366.svs Detections.txt Number:  46 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747366.svs Detections.txt
# Data shape is: (7575, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    6553
# Tau        1022
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       917
# CB            84
# Ambiguous     18
# TA             2
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747366.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747367.svs Detections.txt Number:  47 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747367.svs Detections.txt
# Data shape is: (16901, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16533
# Tau          368
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       318
# CB            26
# Ambiguous     11
# TA             9
# NFT            4
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747367.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747368.svs Detections.txt Number:  48 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747368.svs Detections.txt
# Data shape is: (8126, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    7513
# Tau         613
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       563
# CB            24
# Ambiguous     10
# NFT           10
# TA             6
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747368.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747371.svs Detections.txt Number:  49 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747371.svs Detections.txt
# Data shape is: (3826, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    3225
# Tau         601
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       493
# CB            64
# Ambiguous     16
# TA            15
# NFT           13
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747371.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747374.svs Detections.txt Number:  50 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747374.svs Detections.txt
# Data shape is: (13373, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    11946
# Tau         1427
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1282
# CB            104
# Ambiguous      20
# TA             12
# NFT             9
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747374.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747375.svs Detections.txt Number:  51 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747375.svs Detections.txt
# Data shape is: (24950, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    24071
# Tau          879
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       695
# CB           130
# Ambiguous     26
# NFT           20
# TA             8
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747375.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747376.svs Detections.txt Number:  52 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747376.svs Detections.txt
# Data shape is: (24722, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    21541
# Tau         3181
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2215
# CB            758
# NFT            98
# Ambiguous      64
# TA             46
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747376.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747377.svs Detections.txt Number:  53 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747377.svs Detections.txt
# Data shape is: (8848, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    6724
# Tau        2124
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1748
# CB            258
# Ambiguous      47
# TA             46
# NFT            25
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747377.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747378.svs Detections.txt Number:  54 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747378.svs Detections.txt
# Data shape is: (16822, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16551
# Tau          271
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       259
# CB            10
# TA             1
# Ambiguous      1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747378.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747380.svs Detections.txt Number:  55 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747380.svs Detections.txt
# Data shape is: (29937, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    28406
# Tau         1483
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1401
# CB             56
# Ambiguous      18
# NFT             4
# TA              4
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747380.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747386.svs Detections.txt Number:  56 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747386.svs Detections.txt
# Data shape is: (16955, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16432
# Tau          523
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       485
# CB            26
# Ambiguous      7
# TA             4
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747386.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747390.svs Detections.txt Number:  57 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747390.svs Detections.txt
# Data shape is: (678, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    453
# Tau        225
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       209
# CB            10
# Ambiguous      5
# TA             1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747390.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747813.svs Detections.txt Number:  58 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747813.svs Detections.txt
# Data shape is: (73479, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    72206
# Tau         1273
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1033
# CB            109
# Ambiguous      76
# NFT            29
# TA             26
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747813.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747830.svs Detections.txt Number:  59 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747830.svs Detections.txt
# Data shape is: (3527, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    2450
# Tau        1077
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       906
# CB            70
# NFT           46
# Ambiguous     34
# TA            21
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747830.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747832.svs Detections.txt Number:  60 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747832.svs Detections.txt
# Data shape is: (21625, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    19128
# Tau         2497
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2164
# CB            197
# TA             63
# Ambiguous      44
# NFT            29
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747832.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747833.svs Detections.txt Number:  61 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747833.svs Detections.txt
# Data shape is: (17530, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16798
# Tau          732
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       610
# CB            79
# TA            32
# Ambiguous     11
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747833.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747834.svs Detections.txt Number:  62 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747834.svs Detections.txt
# Data shape is: (8002, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Tau        4612
# Non_tau    3390
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       3965
# CB            335
# TA            174
# Ambiguous      89
# NFT            49
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747834.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747837.svs Detections.txt Number:  63 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747837.svs Detections.txt
# Data shape is: (17170, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    15740
# Tau         1430
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1185
# CB            152
# TA             37
# NFT            28
# Ambiguous      28
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747837.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747847.svs Detections.txt Number:  64 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747847.svs Detections.txt
# Data shape is: (48646, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    45422
# Tau         3224
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2888
# CB            242
# Ambiguous      38
# TA             34
# NFT            22
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747847.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 747848.svs Detections.txt Number:  65 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747848.svs Detections.txt
# Data shape is: (9643, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    8365
# Tau        1278
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1070
# CB             76
# TA             65
# Ambiguous      57
# NFT            10
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  747848.svs Detections.txt
# ...
# Others       1834
# CB             64
# Ambiguous      34
# NFT            31
# TA             27
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771852.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771853.svs Detections.txt Number:  140 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771853.svs Detections.txt
# Data shape is: (12591, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Tau        9470
# Non_tau    3121
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       8178
# CB            600
# NFT           290
# TA            248
# Ambiguous     154
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771853.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771863.svs Detections.txt Number:  141 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771863.svs Detections.txt
# Data shape is: (24064, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    16936
# Tau         7128
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6079
# CB            491
# TA            397
# Ambiguous     113
# NFT            48
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771863.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771865.svs Detections.txt Number:  142 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771865.svs Detections.txt
# Data shape is: (62323, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    57351
# Tau         4972
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       4458
# CB            284
# Ambiguous      93
# TA             72
# NFT            65
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771865.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771866.svs Detections.txt Number:  143 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771866.svs Detections.txt
# Data shape is: (17136, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    15866
# Tau         1270
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       992
# CB           166
# TA            44
# NFT           41
# Ambiguous     27
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771866.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771876.svs Detections.txt Number:  144 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771876.svs Detections.txt
# Data shape is: (35446, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    33817
# Tau         1629
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1518
# CB             76
# Ambiguous      13
# TA             12
# NFT            10
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771876.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771892.svs Detections.txt Number:  145 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771892.svs Detections.txt
# Data shape is: (13884, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Tau        8697
# Non_tau    5187
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6869
# CB           1049
# TA            433
# Ambiguous     218
# NFT           128
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771892.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771893.svs Detections.txt Number:  146 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771893.svs Detections.txt
# Data shape is: (17994, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    13811
# Tau         4183
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       3302
# CB            461
# TA            239
# Ambiguous     110
# NFT            71
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771893.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771894.svs Detections.txt Number:  147 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771894.svs Detections.txt
# Data shape is: (26179, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Tau        18056
# Non_tau     8123
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       13749
# CB            2252
# TA            1042
# Ambiguous      678
# NFT            335
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771894.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771895.svs Detections.txt Number:  148 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771895.svs Detections.txt
# Data shape is: (30628, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    22467
# Tau         8161
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       6333
# CB           1155
# TA            305
# Ambiguous     233
# NFT           135
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771895.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771896.svs Detections.txt Number:  149 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771896.svs Detections.txt
# Data shape is: (10859, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    7898
# Tau        2961
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       2391
# CB            295
# TA            111
# Ambiguous     108
# NFT            56
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771896.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771897.svs Detections.txt Number:  150 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771897.svs Detections.txt
# Data shape is: (9866, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    7804
# Tau        2062
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1689
# CB            210
# TA             69
# Ambiguous      49
# NFT            45
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771897.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771898.svs Detections.txt Number:  151 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771898.svs Detections.txt
# Data shape is: (5528, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    3422
# Tau        2106
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1748
# CB            206
# TA             74
# Ambiguous      56
# NFT            22
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771898.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 771899.svs Detections.txt Number:  152 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771899.svs Detections.txt
# Data shape is: (23670, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    21365
# Tau         2305
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1667
# CB            390
# TA            116
# NFT            82
# Ambiguous      50
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  771899.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772013.svs Detections.txt Number:  153 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772013.svs Detections.txt
# Data shape is: (4444, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    2949
# Tau        1495
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       1390
# CB             61
# Ambiguous      20
# NFT            16
# TA              8
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772013.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772014.svs Detections.txt Number:  154 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772014.svs Detections.txt
# Data shape is: (13747, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    12819
# Tau          928
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       855
# CB            42
# Ambiguous     15
# NFT            9
# TA             7
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772014.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772016.svs Detections.txt Number:  155 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772016.svs Detections.txt
# Data shape is: (9286, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    8257
# Tau        1029
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       973
# CB            31
# TA            16
# Ambiguous      8
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772016.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772017.svs Detections.txt Number:  156 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772017.svs Detections.txt
# Data shape is: (6661, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    6119
# Tau         542
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       492
# CB            26
# Ambiguous     11
# TA             8
# NFT            5
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772017.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772018.svs Detections.txt Number:  157 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772018.svs Detections.txt
# Data shape is: (4334, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    3646
# Tau         688
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       638
# CB            28
# Ambiguous     11
# TA             6
# NFT            5
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772018.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772019.svs Detections.txt Number:  158 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772019.svs Detections.txt
# Data shape is: (4861, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    4213
# Tau         648
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       597
# CB            30
# Ambiguous     11
# TA             6
# NFT            4
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772019.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772020.svs Detections.txt Number:  159 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772020.svs Detections.txt
# Data shape is: (2729, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    2399
# Tau         330
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       300
# CB            19
# NFT            6
# Ambiguous      4
# TA             1
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772020.svs Detections.txt
# ----------------------------------------------------------------------------
# FILE 772922.svs Detections.txt Number:  160 / 160
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772922.svs Detections.txt
# Data shape is: (3489, 61)
# ---------------STEP2: SEPARATING NON-TAU FROM TAU using Classifier1 -------------------
# Non_tau    2923
# Tau         566
# Name: Class, dtype: int64
# ---------------STEP4: Tau hallmark classification using Classifier2 -------------------
# Others       530
# CB            19
# Ambiguous      8
# TA             6
# NFT            3
# Name: Class, dtype: int64
# ---------------STEP5: DATA EXTRACTION & EXPORT-------------------
# No loss of cells?  True
# Exported prediction of :  772922.svs Detections.txt
# ----------------------------------------------------------------------------
# **********ALL DONE! YAY, no error!***********
