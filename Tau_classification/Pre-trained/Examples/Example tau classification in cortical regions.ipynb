# %% [markdown]
# ## Example script: training tau classifier for cortical regions

# %% [markdown]
# **Read in relevant files**

# %%
import sys
sys.path.insert(0,
                '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/')

from base import *
from constants import *
from tau_classification import *
import joblib

# %% [markdown]
# ### Load pre-trained models

# %% [markdown]
# **Screening classifier**

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Pre-trained/Models/"
filename = "screening_classifier_updated3.sav"
screening_model = joblib.load(path+filename)

# %%
# Some checks
print(screening_model.pipeline)
screening_model.f_importance.head()
# Out:
# Pipeline(steps=[('normalizer', MinMaxScaler()),
#                 ('selector',
#                  RFE(estimator=RandomForestClassifier(random_state=42),
#                      n_features_to_select=46)),
#                 ('clf',
#                  BalancedRandomForestClassifier(class_weight='balanced',
#                                                 max_features=1,
#                                                 min_samples_leaf=2,
#                                                 n_estimators=600,
#                                                 random_state=42))])
#                                              features  importance
# 33          ROI: 0.25 µm per pixel: Hematoxylin: Mean    0.043437
# 34        ROI: 0.25 µm per pixel: Hematoxylin: Median    0.041947
# 37                  ROI: 0.25 µm per pixel: Red: Mean    0.038536
# 36                   ROI: 0.25 µm per pixel: Red: Max    0.036822
# 19  ROI: 0.25 µm per pixel: DAB: Haralick Sum aver...    0.034232

# %% [markdown]
# **Tau classifier for cortical regions**

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Pre-trained/Models/"
filename = "cortical_classifier_updated3.sav"
cortical_model = joblib.load(path+filename)

# %%
print(cortical_model.best_parameters)
cortical_model.f_importance.head()
# Out:
# {0: (0.20178264912940796, 0.9461222841732907, 0.9392187191317515, 0.9545454545454545), 1: (0.6822153285884559, 0.9098161065987153, 0.9409706959706959, 0.8903846153846153), 2: (0.7611313612515783, 0.9922817367544002, 0.9921489382138381, 0.9924504542672882), 3: (0.5047927492593813, 0.9566895472267282, 0.9541859991859992, 0.960923076923077)}
#                                features  importance
# 4                       Min diameter µm    0.129815
# 0                             Area µm^2    0.129211
# 2                             Length µm    0.091414
# 3                       Max diameter µm    0.067562
# 20  ROI: 0.25 µm per pixel: DAB: Median    0.049342

# %% [markdown]
# ### Putting them together: tau classification pipeline for novel *cortical* slides

# %%
novel_path = '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Detections/cortical/'
novel_filename = 'detections.txt'
prediction_path = "C:/Users/mokur/OneDrive/Desktop/Digital_path/Predictions/Cortical/"

# %% [markdown]
# **Reading in files**

# %%
with open(novel_path + novel_filename) as f:
    mylist = f.read().splitlines()

print("Read in: ", len(mylist), "files")
# Out:
# Read in:  222 files

# %% [markdown]
# #### Tau classification

# %%
n_total = len(mylist)
faulty_file = []
for i in range(0, n_total):

    # Read in novel slide
    print("FILE", mylist[i], "Number: ", i + 1, "/", n_total)
    print("---------------STEP1: Read in data file -------------------")
    dat_file = mylist[i]

    dat_ = pd.read_csv(novel_path + dat_file, sep="\t")

    # Fixing order of the columns
    ordered = dat_[extracted_features]

    # Changing column names
    # since these names tend to be inconsistent causing problems
    ordered.columns.values[5] = "Centroid_X"
    ordered.columns.values[6] = "Centroid_Y"



    dat = ordered[ordered["Class"] == "Unlabelled"]  # only unlabelled cells
    print("Read in data file:", dat_file)
    print("Data shape is:", dat.shape)

    # Classifier 1: separating Non-tau from Tau
    print(
        "---------------STEP2: Separating Non-tau from Tau -------------------"
    )
    # 1) Remove NA cells
    dat = dat.dropna()

    predicted1_slide = dat.copy()

    # 2) Dropping extra info features
    X_unlabelled = dat.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"]
    )
    # 3) Predictions
    screening_model.predict(X_unlabelled)
    predicted1_slide["Class"] = screening_model.prediction
    print(predicted1_slide["Class"].value_counts())

    # Classifier 2: tau hallmark classification
    print(
        "---------------STEP3: Tau hallmark classification -------------------"
    )
    # Select out 'tau' portion only (ignoring non-tau & ambiguous cells )
    tau_portion = predicted1_slide[predicted1_slide["Class"] == "Tau"]
    if tau_portion.shape[0] == 0:
        print("There is no tau on this slide!")
        faulty_file.append(dat["Image"][0] + " No tau on the slide")
        continue
    tau_portion_X = tau_portion.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"])
    predicted2_slide = tau_portion.copy()
    # Separates out detections that are not tau
    non_tau_portion = predicted1_slide[predicted1_slide["Class"] != "Tau"]

    # Make predictions on Tau objects
    cortical_model.predict(tau_portion_X)
    predicted2_slide["Class"] = cortical_model.prediction
    print(predicted2_slide["Class"].value_counts())

    # Extracting data out
    print("---------------STEP4: Data extraction & export -------------------")

    # 1) Combining predicted cells & excluded cells (prior to prediction)
    total_pred = pd.concat([non_tau_portion,
                            predicted2_slide])
    print("No loss of cells? ",
          predicted1_slide.shape[0] == total_pred.shape[0])

    output_visualise = total_pred[["Image",
                                   "Class",
                                   "Centroid_X",
                                   "Centroid_Y",
                                   "Area µm^2"]]
    path_ = (
            prediction_path +
            output_visualise.iloc[0, 0] +
            "_predictions.txt"
            )
    output_visualise.to_csv(path_, sep="\t", index=False)

    print("Exported prediction of : ", dat_file)
    print("---------------------------------------------------")
print("Well done, no error!")
# Out:
# FILE 703471.svs Detections.txt Number:  1 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703471.svs Detections.txt
# Data shape is: (41670, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    35077
# Tau         6593
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       4576
# CB           1707
# Ambiguous     137
# NFT            96
# TA             77
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703471.svs Detections.txt
# ---------------------------------------------------
# FILE 703472.svs Detections.txt Number:  2 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703472.svs Detections.txt
# Data shape is: (80333, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    79235
# Tau         1098
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       648
# CB           391
# NFT           31
# Ambiguous     24
# TA             4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703472.svs Detections.txt
# ---------------------------------------------------
# FILE 703473.svs Detections.txt Number:  3 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703473.svs Detections.txt
# Data shape is: (82112, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    76833
# Tau         5279
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3345
# CB           1707
# NFT           120
# Ambiguous      77
# TA             30
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703473.svs Detections.txt
# ---------------------------------------------------
# FILE 703482.svs Detections.txt Number:  4 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703482.svs Detections.txt
# Data shape is: (6653, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    5493
# Tau        1160
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       857
# CB           263
# Ambiguous     27
# NFT            7
# TA             6
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703482.svs Detections.txt
# ---------------------------------------------------
# FILE 703483.svs Detections.txt Number:  5 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703483.svs Detections.txt
# Data shape is: (32686, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    17524
# Tau        15162
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       11006
# CB            3640
# Ambiguous      216
# TA             164
# NFT            136
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703483.svs Detections.txt
# ---------------------------------------------------
# FILE 703484.svs Detections.txt Number:  6 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703484.svs Detections.txt
# Data shape is: (12661, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    11483
# Tau         1178
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       831
# CB           308
# Ambiguous     18
# NFT           14
# TA             7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703484.svs Detections.txt
# ---------------------------------------------------
# FILE 703485.svs Detections.txt Number:  7 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703485.svs Detections.txt
# Data shape is: (4932, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3438
# Tau        1494
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1189
# CB            235
# NFT            40
# Ambiguous      23
# TA              7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703485.svs Detections.txt
# ---------------------------------------------------
# FILE 703516.svs Detections.txt Number:  8 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703516.svs Detections.txt
# Data shape is: (7348, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    6537
# Tau         811
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       626
# CB           171
# TA             8
# Ambiguous      6
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703516.svs Detections.txt
# ---------------------------------------------------
# FILE 703517.svs Detections.txt Number:  9 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703517.svs Detections.txt
# Data shape is: (17444, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    10863
# Tau         6581
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5419
# CB           1008
# TA             86
# Ambiguous      63
# NFT             5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703517.svs Detections.txt
# ---------------------------------------------------
# FILE 703518.svs Detections.txt Number:  10 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703518.svs Detections.txt
# Data shape is: (32999, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    26618
# Tau         6381
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       4863
# CB           1251
# TA            155
# Ambiguous     100
# NFT            12
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703518.svs Detections.txt
# ---------------------------------------------------
# FILE 703519.svs Detections.txt Number:  11 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703519.svs Detections.txt
# Data shape is: (15256, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13998
# Tau         1258
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       960
# CB           260
# TA            17
# Ambiguous     16
# NFT            5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703519.svs Detections.txt
# ---------------------------------------------------
# FILE 703520.svs Detections.txt Number:  12 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703520.svs Detections.txt
# Data shape is: (14423, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13958
# Tau          465
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       379
# CB            60
# TA            18
# Ambiguous      8
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703520.svs Detections.txt
# ---------------------------------------------------
# FILE 703521.svs Detections.txt Number:  13 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703521.svs Detections.txt
# Data shape is: (18261, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    18147
# Tau          114
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others    100
# CB         12
# TA          1
# NFT         1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703521.svs Detections.txt
# ---------------------------------------------------
# FILE 703522.svs Detections.txt Number:  14 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703522.svs Detections.txt
# Data shape is: (13321, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13074
# Tau          247
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       214
# CB            31
# Ambiguous      2
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703522.svs Detections.txt
# ---------------------------------------------------
# FILE 703523.svs Detections.txt Number:  15 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 703523.svs Detections.txt
# Data shape is: (5040, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    4643
# Tau         397
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       324
# CB            61
# TA             8
# NFT            2
# Ambiguous      2
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703523.svs Detections.txt
# ---------------------------------------------------
# FILE 721698.svs Detections.txt Number:  16 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721698.svs Detections.txt
# Data shape is: (17513, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    16426
# Tau         1087
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       777
# CB           228
# Ambiguous     31
# NFT           30
# TA            21
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721698.svs Detections.txt
# ---------------------------------------------------
# FILE 721699.svs Detections.txt Number:  17 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721699.svs Detections.txt
# Data shape is: (33918, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    31573
# Tau         2345
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1622
# CB            623
# Ambiguous      46
# TA             35
# NFT            19
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721699.svs Detections.txt
# ---------------------------------------------------
# FILE 721700.svs Detections.txt Number:  18 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721700.svs Detections.txt
# Data shape is: (25934, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    17959
# Tau         7975
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6056
# CB           1385
# TA            230
# Ambiguous     156
# NFT           148
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721700.svs Detections.txt
# ---------------------------------------------------
# FILE 721701.svs Detections.txt Number:  19 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721701.svs Detections.txt
# Data shape is: (41634, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    37246
# Tau         4388
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3309
# CB            892
# NFT            74
# Ambiguous      68
# TA             45
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721701.svs Detections.txt
# ---------------------------------------------------
# FILE 721702.svs Detections.txt Number:  20 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721702.svs Detections.txt
# Data shape is: (21996, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    20971
# Tau         1025
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       746
# CB           185
# NFT           34
# Ambiguous     32
# TA            28
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721702.svs Detections.txt
# ---------------------------------------------------
# FILE 721703.svs Detections.txt Number:  21 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721703.svs Detections.txt
# Data shape is: (12208, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    11881
# Tau          327
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       278
# CB            38
# Ambiguous      8
# TA             2
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721703.svs Detections.txt
# ---------------------------------------------------
# FILE 721704.svs Detections.txt Number:  22 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721704.svs Detections.txt
# Data shape is: (37106, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    36598
# Tau          507
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       429
# CB            48
# NFT           14
# Ambiguous      9
# TA             7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721704.svs Detections.txt
# ---------------------------------------------------
# FILE 721705.svs Detections.txt Number:  23 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721705.svs Detections.txt
# Data shape is: (7527, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    7348
# Tau         179
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       118
# CB            44
# NFT           13
# Ambiguous      3
# TA             1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721705.svs Detections.txt
# ---------------------------------------------------
# FILE 721731.svs Detections.txt Number:  24 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721731.svs Detections.txt
# Data shape is: (33175, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    28430
# Tau         4745
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3783
# CB            765
# TA            111
# Ambiguous      61
# NFT            25
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721731.svs Detections.txt
# ---------------------------------------------------
# FILE 721732.svs Detections.txt Number:  25 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721732.svs Detections.txt
# Data shape is: (109260, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    78357
# Tau        30903
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       24291
# CB            4566
# TA            1319
# Ambiguous      546
# NFT            181
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721732.svs Detections.txt
# ---------------------------------------------------
# FILE 721733.svs Detections.txt Number:  26 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721733.svs Detections.txt
# Data shape is: (47693, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    38750
# Tau         8943
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       7086
# CB           1352
# TA            313
# Ambiguous     153
# NFT            39
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721733.svs Detections.txt
# ---------------------------------------------------
# FILE 721734.svs Detections.txt Number:  27 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721734.svs Detections.txt
# Data shape is: (30680, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    22421
# Tau         8259
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6412
# CB           1504
# TA            155
# Ambiguous     124
# NFT            64
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721734.svs Detections.txt
# ---------------------------------------------------
# FILE 721735.svs Detections.txt Number:  28 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721735.svs Detections.txt
# Data shape is: (23375, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    16485
# Tau         6890
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5629
# CB            930
# TA            180
# Ambiguous     109
# NFT            42
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721735.svs Detections.txt
# ---------------------------------------------------
# FILE 721770.svs Detections.txt Number:  29 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721770.svs Detections.txt
# Data shape is: (15795, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    14503
# Tau         1292
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1058
# CB            156
# TA             52
# Ambiguous      23
# NFT             3
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721770.svs Detections.txt
# ---------------------------------------------------
# FILE 721771.svs Detections.txt Number:  30 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721771.svs Detections.txt
# Data shape is: (43212, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    42354
# Tau          857
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       625
# CB           154
# TA            29
# Ambiguous     25
# NFT           24
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721771.svs Detections.txt
# ---------------------------------------------------
# FILE 721772.svs Detections.txt Number:  31 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721772.svs Detections.txt
# Data shape is: (45323, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    37768
# Tau         7555
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6260
# CB           1033
# TA            104
# Ambiguous      99
# NFT            59
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721772.svs Detections.txt
# ---------------------------------------------------
# FILE 721851.svs Detections.txt Number:  32 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721851.svs Detections.txt
# Data shape is: (57422, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    56502
# Tau          920
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       604
# CB           278
# NFT           21
# Ambiguous     16
# TA             1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721851.svs Detections.txt
# ---------------------------------------------------
# FILE 721852.svs Detections.txt Number:  33 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721852.svs Detections.txt
# Data shape is: (45865, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    45399
# Tau          466
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       347
# CB            99
# NFT            9
# Ambiguous      6
# TA             5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721852.svs Detections.txt
# ---------------------------------------------------
# FILE 721853.svs Detections.txt Number:  34 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721853.svs Detections.txt
# Data shape is: (63494, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    61916
# Tau         1578
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1104
# CB            393
# NFT            41
# Ambiguous      36
# TA              4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721853.svs Detections.txt
# ---------------------------------------------------
# FILE 721854.svs Detections.txt Number:  35 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721854.svs Detections.txt
# Data shape is: (65193, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    64743
# Tau          450
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       263
# CB           167
# Ambiguous     13
# NFT            4
# TA             3
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721854.svs Detections.txt
# ---------------------------------------------------
# FILE 721855.svs Detections.txt Number:  36 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721855.svs Detections.txt
# Data shape is: (46940, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    46562
# Tau          378
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       260
# CB           109
# Ambiguous      5
# NFT            3
# TA             1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721855.svs Detections.txt
# ---------------------------------------------------
# FILE 721856.svs Detections.txt Number:  37 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721856.svs Detections.txt
# Data shape is: (90374, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    80845
# Tau         9529
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5656
# CB           3222
# NFT           341
# Ambiguous     236
# TA             74
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721856.svs Detections.txt
# ---------------------------------------------------
# FILE 721863.svs Detections.txt Number:  38 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 721863.svs Detections.txt
# Data shape is: (23577, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    20929
# Tau         2648
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       2028
# CB            379
# Ambiguous     105
# NFT           100
# TA             36
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721863.svs Detections.txt
# ---------------------------------------------------
# FILE 722215.svs Detections.txt Number:  39 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 722215.svs Detections.txt
# Data shape is: (3515, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        2802
# Non_tau     713
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       2296
# CB            388
# Ambiguous      64
# NFT            35
# TA             19
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  722215.svs Detections.txt
# ---------------------------------------------------
# FILE 747283.svs Detections.txt Number:  40 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747283.svs Detections.txt
# Data shape is: (7074, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    5097
# Tau        1977
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1799
# TA             68
# CB             63
# Ambiguous      43
# NFT             4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747283.svs Detections.txt
# ---------------------------------------------------
# FILE 747310.svs Detections.txt Number:  41 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747310.svs Detections.txt
# Data shape is: (23361, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    18932
# Tau         4429
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3667
# Ambiguous     387
# CB            262
# NFT            64
# TA             49
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747310.svs Detections.txt
# ---------------------------------------------------
# FILE 747311.svs Detections.txt Number:  42 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747311.svs Detections.txt
# Data shape is: (21160, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13374
# Tau         7786
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6550
# Ambiguous     742
# CB            279
# NFT           112
# TA            103
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747311.svs Detections.txt
# ---------------------------------------------------
# FILE 747313.svs Detections.txt Number:  43 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747313.svs Detections.txt
# Data shape is: (30026, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    22221
# Tau         7805
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6426
# Ambiguous     633
# CB            516
# TA            131
# NFT            99
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747313.svs Detections.txt
# ---------------------------------------------------
# FILE 747316.svs Detections.txt Number:  44 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747316.svs Detections.txt
# Data shape is: (36440, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    19524
# Tau        16916
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       13294
# CB            2352
# TA             673
# Ambiguous      322
# NFT            275
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747316.svs Detections.txt
# ---------------------------------------------------
# FILE 747317.svs Detections.txt Number:  45 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747317.svs Detections.txt
# Data shape is: (45386, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    41627
# Tau         3759
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       2876
# CB            542
# TA            201
# Ambiguous      96
# NFT            44
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747317.svs Detections.txt
# ---------------------------------------------------
# FILE 747318.svs Detections.txt Number:  46 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747318.svs Detections.txt
# Data shape is: (17948, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    16600
# Tau         1348
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1159
# CB             81
# TA             55
# Ambiguous      37
# NFT            16
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747318.svs Detections.txt
# ---------------------------------------------------
# FILE 747320.svs Detections.txt Number:  47 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747320.svs Detections.txt
# Data shape is: (42119, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    39961
# Tau         2158
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1551
# CB            455
# TA             78
# Ambiguous      51
# NFT            23
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747320.svs Detections.txt
# ---------------------------------------------------
# FILE 747322.svs Detections.txt Number:  48 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747322.svs Detections.txt
# Data shape is: (31423, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    26558
# Tau         4865
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       4069
# TA            329
# CB            289
# Ambiguous     149
# NFT            29
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747322.svs Detections.txt
# ---------------------------------------------------
# FILE 747323.svs Detections.txt Number:  49 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747323.svs Detections.txt
# Data shape is: (43766, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    43529
# Tau          237
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       225
# CB             7
# NFT            3
# Ambiguous      1
# TA             1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747323.svs Detections.txt
# ---------------------------------------------------
# FILE 747324.svs Detections.txt Number:  50 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747324.svs Detections.txt
# Data shape is: (1540, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    1256
# Tau         284
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       256
# CB            17
# Ambiguous      5
# TA             5
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747324.svs Detections.txt
# ---------------------------------------------------
# FILE 747325.svs Detections.txt Number:  51 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747325.svs Detections.txt
# Data shape is: (13403, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    12352
# Tau         1051
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       675
# CB           312
# Ambiguous     32
# NFT           25
# TA             7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747325.svs Detections.txt
# ---------------------------------------------------
# FILE 747326.svs Detections.txt Number:  52 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747326.svs Detections.txt
# Data shape is: (32140, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    24908
# Tau         7232
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5371
# CB           1289
# Ambiguous     384
# NFT            96
# TA             92
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747326.svs Detections.txt
# ---------------------------------------------------
# FILE 747327.svs Detections.txt Number:  53 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747327.svs Detections.txt
# Data shape is: (37601, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    26371
# Tau        11230
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       10714
# TA             195
# CB             186
# Ambiguous       86
# NFT             49
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747327.svs Detections.txt
# ---------------------------------------------------
# FILE 747329.svs Detections.txt Number:  54 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747329.svs Detections.txt
# Data shape is: (12299, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    9523
# Tau        2776
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       2285
# CB            354
# TA             61
# Ambiguous      47
# NFT            29
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747329.svs Detections.txt
# ---------------------------------------------------
# FILE 747330.svs Detections.txt Number:  55 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747330.svs Detections.txt
# Data shape is: (8911, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    8223
# Tau         688
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       476
# CB           155
# NFT           34
# Ambiguous     18
# TA             5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747330.svs Detections.txt
# ---------------------------------------------------
# FILE 747331.svs Detections.txt Number:  56 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747331.svs Detections.txt
# Data shape is: (13576, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    10999
# Tau         2577
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1949
# CB            434
# Ambiguous      73
# NFT            66
# TA             55
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747331.svs Detections.txt
# ---------------------------------------------------
# FILE 747338.svs Detections.txt Number:  57 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747338.svs Detections.txt
# Data shape is: (27988, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    22273
# Tau         5715
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       4660
# CB            735
# TA            136
# Ambiguous     108
# NFT            76
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747338.svs Detections.txt
# ---------------------------------------------------
# FILE 747339.svs Detections.txt Number:  58 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747339.svs Detections.txt
# Data shape is: (24166, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    23698
# Tau          468
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       422
# CB            36
# NFT            4
# Ambiguous      4
# TA             2
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747339.svs Detections.txt
# ---------------------------------------------------
# FILE 747361.svs Detections.txt Number:  59 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747361.svs Detections.txt
# Data shape is: (6893, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    6574
# Tau         319
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       302
# CB             8
# Ambiguous      5
# TA             4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747361.svs Detections.txt
# ---------------------------------------------------
# FILE 747364.svs Detections.txt Number:  60 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747364.svs Detections.txt
# Data shape is: (19505, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    18925
# Tau          580
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       538
# CB            29
# TA             6
# Ambiguous      6
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747364.svs Detections.txt
# ---------------------------------------------------
# FILE 747365.svs Detections.txt Number:  61 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747365.svs Detections.txt
# Data shape is: (19745, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    19514
# Tau          231
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       206
# CB            13
# Ambiguous     12
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747365.svs Detections.txt
# ---------------------------------------------------
# FILE 747366.svs Detections.txt Number:  62 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747366.svs Detections.txt
# Data shape is: (7575, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    7402
# Tau         173
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       143
# CB            25
# Ambiguous      4
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747366.svs Detections.txt
# ---------------------------------------------------
# FILE 747367.svs Detections.txt Number:  63 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747367.svs Detections.txt
# Data shape is: (16878, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    16740
# Tau          138
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       117
# Ambiguous     13
# CB             7
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747367.svs Detections.txt
# ---------------------------------------------------
# FILE 747368.svs Detections.txt Number:  64 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747368.svs Detections.txt
# Data shape is: (8063, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    7708
# Tau         355
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       331
# CB            11
# NFT            7
# Ambiguous      6
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747368.svs Detections.txt
# ---------------------------------------------------
# FILE 747371.svs Detections.txt Number:  65 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747371.svs Detections.txt
# Data shape is: (3737, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3369
# Tau         368
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       299
# CB            60
# NFT            5
# Ambiguous      4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747371.svs Detections.txt
# ---------------------------------------------------
# FILE 747372.svs Detections.txt Number:  66 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747372.svs Detections.txt
# Data shape is: (21718, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    19281
# Tau         2437
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1862
# CB            371
# Ambiguous     139
# TA             45
# NFT            20
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747372.svs Detections.txt
# ---------------------------------------------------
# FILE 747374.svs Detections.txt Number:  67 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747374.svs Detections.txt
# Data shape is: (13373, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    12350
# Tau         1023
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       906
# CB            98
# TA            10
# Ambiguous      5
# NFT            4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747374.svs Detections.txt
# ---------------------------------------------------
# FILE 747375.svs Detections.txt Number:  68 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747375.svs Detections.txt
# Data shape is: (24950, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    24309
# Tau          641
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       491
# CB           121
# Ambiguous     16
# NFT            8
# TA             5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747375.svs Detections.txt
# ---------------------------------------------------
# FILE 747376.svs Detections.txt Number:  69 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747376.svs Detections.txt
# Data shape is: (24722, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    22087
# Tau         2635
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1745
# CB            769
# Ambiguous      50
# NFT            45
# TA             26
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747376.svs Detections.txt
# ---------------------------------------------------
# FILE 747377.svs Detections.txt Number:  70 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 747377.svs Detections.txt
# Data shape is: (8848, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    6989
# Tau        1859
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1522
# CB            262
# TA             31
# Ambiguous      29
# NFT            15
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747377.svs Detections.txt
# ...
# No loss of cells?  True
# Exported prediction of :  771861.svs Detections.txt
# ---------------------------------------------------
# FILE 771862.svs Detections.txt Number:  200 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771862.svs Detections.txt
# Data shape is: (62208, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        53334
# Non_tau     8874
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       46782
# CB            3237
# TA            2342
# Ambiguous      797
# NFT            176
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771862.svs Detections.txt
# ---------------------------------------------------
# FILE 771863.svs Detections.txt Number:  201 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771863.svs Detections.txt
# Data shape is: (24064, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    17500
# Tau         6564
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5667
# CB            455
# TA            310
# Ambiguous     107
# NFT            25
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771863.svs Detections.txt
# ---------------------------------------------------
# FILE 771864.svs Detections.txt Number:  202 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771864.svs Detections.txt
# Data shape is: (15061, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    9866
# Tau        5195
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       4229
# CB            723
# TA            127
# Ambiguous      85
# NFT            31
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771864.svs Detections.txt
# ---------------------------------------------------
# FILE 771865.svs Detections.txt Number:  203 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771865.svs Detections.txt
# Data shape is: (62323, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    58776
# Tau         3547
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3138
# CB            272
# Ambiguous      52
# TA             50
# NFT            35
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771865.svs Detections.txt
# ---------------------------------------------------
# FILE 771866.svs Detections.txt Number:  204 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771866.svs Detections.txt
# Data shape is: (17136, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    16095
# Tau         1041
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       810
# CB           146
# TA            36
# NFT           32
# Ambiguous     17
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771866.svs Detections.txt
# ---------------------------------------------------
# FILE 771876.svs Detections.txt Number:  205 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771876.svs Detections.txt
# Data shape is: (35446, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    34325
# Tau         1121
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1050
# CB             50
# Ambiguous      12
# TA              5
# NFT             4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771876.svs Detections.txt
# ---------------------------------------------------
# FILE 771892.svs Detections.txt Number:  206 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771892.svs Detections.txt
# Data shape is: (13884, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        7873
# Non_tau    6011
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       6242
# CB           1088
# TA            305
# Ambiguous     195
# NFT            43
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771892.svs Detections.txt
# ---------------------------------------------------
# FILE 771893.svs Detections.txt Number:  207 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771893.svs Detections.txt
# Data shape is: (17994, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    14210
# Tau         3784
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       3019
# CB            457
# TA            188
# Ambiguous      90
# NFT            30
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771893.svs Detections.txt
# ---------------------------------------------------
# FILE 771894.svs Detections.txt Number:  208 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771894.svs Detections.txt
# Data shape is: (26179, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        16775
# Non_tau     9404
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       12975
# CB            2385
# TA             712
# Ambiguous      575
# NFT            128
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771894.svs Detections.txt
# ---------------------------------------------------
# FILE 771895.svs Detections.txt Number:  209 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771895.svs Detections.txt
# Data shape is: (30628, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    23627
# Tau         7001
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       5390
# CB           1204
# TA            201
# Ambiguous     165
# NFT            41
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771895.svs Detections.txt
# ---------------------------------------------------
# FILE 771896.svs Detections.txt Number:  210 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771896.svs Detections.txt
# Data shape is: (10859, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    8253
# Tau        2606
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       2121
# CB            309
# Ambiguous      77
# TA             73
# NFT            26
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771896.svs Detections.txt
# ---------------------------------------------------
# FILE 771897.svs Detections.txt Number:  211 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771897.svs Detections.txt
# Data shape is: (9866, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    8205
# Tau        1661
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1342
# CB            219
# TA             41
# Ambiguous      40
# NFT            19
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771897.svs Detections.txt
# ---------------------------------------------------
# FILE 771898.svs Detections.txt Number:  212 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771898.svs Detections.txt
# Data shape is: (5528, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3700
# Tau        1828
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1535
# CB            200
# TA             53
# Ambiguous      29
# NFT            11
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771898.svs Detections.txt
# ---------------------------------------------------
# FILE 771899.svs Detections.txt Number:  213 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 771899.svs Detections.txt
# Data shape is: (23670, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    21731
# Tau         1939
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1401
# CB            355
# TA             91
# NFT            53
# Ambiguous      39
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771899.svs Detections.txt
# ---------------------------------------------------
# FILE 772013.svs Detections.txt Number:  214 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772013.svs Detections.txt
# Data shape is: (4444, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3407
# Tau        1037
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       968
# CB            40
# Ambiguous     17
# NFT            9
# TA             3
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772013.svs Detections.txt
# ---------------------------------------------------
# FILE 772014.svs Detections.txt Number:  215 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772014.svs Detections.txt
# Data shape is: (13747, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13254
# Tau          493
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       455
# CB            26
# Ambiguous      5
# NFT            4
# TA             3
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772014.svs Detections.txt
# ---------------------------------------------------
# FILE 772016.svs Detections.txt Number:  216 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772016.svs Detections.txt
# Data shape is: (9286, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    8788
# Tau         498
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       460
# CB            21
# Ambiguous     10
# TA             6
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772016.svs Detections.txt
# ---------------------------------------------------
# FILE 772017.svs Detections.txt Number:  217 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772017.svs Detections.txt
# Data shape is: (6661, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    6295
# Tau         366
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       329
# CB            21
# TA             6
# Ambiguous      6
# NFT            4
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772017.svs Detections.txt
# ---------------------------------------------------
# FILE 772018.svs Detections.txt Number:  218 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772018.svs Detections.txt
# Data shape is: (4267, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3936
# Tau         331
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       322
# CB             6
# NFT            2
# Ambiguous      1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772018.svs Detections.txt
# ---------------------------------------------------
# FILE 772019.svs Detections.txt Number:  219 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772019.svs Detections.txt
# Data shape is: (4861, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    4511
# Tau         350
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       330
# CB            14
# Ambiguous      3
# NFT            3
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772019.svs Detections.txt
# ---------------------------------------------------
# FILE 772020.svs Detections.txt Number:  220 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772020.svs Detections.txt
# Data shape is: (2729, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    2498
# Tau         231
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others    204
# CB         20
# NFT         6
# TA          1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772020.svs Detections.txt
# ---------------------------------------------------
# FILE 772701.svs Detections.txt Number:  221 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772701.svs Detections.txt
# Data shape is: (16038, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    14724
# Tau         1314
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       1165
# CB             85
# Ambiguous      28
# NFT            24
# TA             12
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772701.svs Detections.txt
# ---------------------------------------------------
# FILE 772922.svs Detections.txt Number:  222 / 222
# ---------------STEP1: Read in data file -------------------
# Read in data file: 772922.svs Detections.txt
# Data shape is: (3489, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    3151
# Tau         338
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Others       317
# CB            13
# Ambiguous      5
# TA             2
# NFT            1
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772922.svs Detections.txt
# ---------------------------------------------------
# Well done, no error!
