# %% [markdown]
# ## Example script: training tau classifier for basal ganglia

# %% [markdown]
# **Read in relevant files**

# %%
import sys
sys.path.insert(0,
                '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/')

from base import *
from constants import *
from tau_classification import * 
import joblib

# %% [markdown]
# ### Load pre-trained models

# %% [markdown]
# **Screening classifier**

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Pre-trained/Models/"
filename = "screening_classifier_updated3.sav"
screening_model = joblib.load(path+filename)

# %%
# Some checks
print(screening_model.pipeline)
screening_model.f_importance.head()
# Out:
# Pipeline(steps=[('normalizer', MinMaxScaler()),
#                 ('selector',
#                  RFE(estimator=RandomForestClassifier(random_state=42),
#                      n_features_to_select=46)),
#                 ('clf',
#                  BalancedRandomForestClassifier(class_weight='balanced',
#                                                 max_features=1,
#                                                 min_samples_leaf=2,
#                                                 n_estimators=600,
#                                                 random_state=42))])
#                                              features  importance
# 33          ROI: 0.25 µm per pixel: Hematoxylin: Mean    0.043437
# 34        ROI: 0.25 µm per pixel: Hematoxylin: Median    0.041947
# 37                  ROI: 0.25 µm per pixel: Red: Mean    0.038536
# 36                   ROI: 0.25 µm per pixel: Red: Max    0.036822
# 19  ROI: 0.25 µm per pixel: DAB: Haralick Sum aver...    0.034232

# %% [markdown]
# **Tau classifier for Striatum**

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Pre-trained/Models/"
filename = "str_classifier.sav"
str_model = joblib.load(path+filename)

# %%
print(str_model.best_parameters)
str_model.f_importance.head()
# Out:
# {0: (0.19564858129927834, 0.8870751195750726, 0.873128875762111, 0.9072192513368984), 1: (0.8264912975852534, 0.9777777777777779, 1.0, 0.96), 2: (0.7613745234867089, 0.991988553025763, 0.9920257276937077, 0.9919779041965537), 3: (0.45007735002598476, 0.9372955624546812, 0.914380764163373, 0.9650000000000001)}
#                                              features  importance
# 0                                           Area µm^2    0.214311
# 4                                     Min diameter µm    0.181223
# 19                  ROI: 0.25 µm per pixel: DAB: Mean    0.168029
# 20                ROI: 0.25 µm per pixel: DAB: Median    0.113468
# 16  ROI: 0.25 µm per pixel: DAB: Haralick Sum aver...    0.079985

# %% [markdown]
# **Tau classifier for Subthalamic nucleus & globus pallidus**

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Tau_pipeline/Tau_classification/Pre-trained/Models/"
filename = "stn_gp_classifier.sav"
stn_gp_model = joblib.load(path+filename)

# %%
print(stn_gp_model.best_parameters)
stn_gp_model.f_importance.head()
# Out:
# {0: (0.18845399342448405, 0.8946962279425845, 0.8965841716432827, 0.9002459016393443), 1: (0.7187865615771717, 0.9529564106344293, 0.9518181818181819, 0.9588888888888889), 2: (0.774700336310272, 0.9956218336556081, 0.9939498939499222, 0.9973053231655025)}
#                              features  importance
# 0                           Area µm^2    0.510403
# 4                     Min diameter µm    0.193240
# 21  ROI: 0.25 µm per pixel: DAB: Mean    0.074044
# 3                     Max diameter µm    0.031333
# 33                           Solidity    0.028362

# %% [markdown]
# ### Putting them together: tau classification pipeline for novel *cortical* slides

# %%
novel_path = '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Detections/BG/'
novel_filename = 'detections.txt'
prediction_path = "C:/Users/mokur/OneDrive/Desktop/Digital_path/Predictions/BG/"

# %% [markdown]
# **Reading in files**

# %%
with open(novel_path + novel_filename) as f:
    mylist = f.read().splitlines()

print("Read in: ", len(mylist), "files")
# Out:
# Read in:  27 files

# %% [markdown]
# #### Tau classification

# %%
code = {'GP':'GP',
        'STN':'STN',
        'STR':'STR',
        'GP_reseg':'GP',
        'STN_reseg':'STN',
        'STR_reseg':'STR'}

# %%
n_total = len(mylist)
faulty_file = []
for i in range(0, n_total):

    # Read in novel slide
    print("FILE", mylist[i], "Number: ", i + 1, "/", n_total)
    print("---------------STEP1: Read in data file -------------------")
    dat_file = mylist[i]

    dat_ = pd.read_csv(novel_path + dat_file, sep="\t")

    # Fixing order of the columns
    ordered = dat_[extracted_features]

    # Changing column names
    # since these names tend to be inconsistent causing problems
    ordered.columns.values[5] = "Centroid_X"
    ordered.columns.values[6] = "Centroid_Y"

    dat_ordered = ordered[ordered["Class"] == "Unlabelled"]  # only unlabelled cells
    dat_parent = dat_ordered['Parent']
    dat = dat_ordered.copy()
    dat.loc[:, 'Parent'] = [code[i] for i in dat_parent]
    print(set(dat['Parent']))
    print("Read in data file:", dat_file)
    print("Data shape is:", dat.shape)

    # Classifier 1: separating Non-tau from Tau
    print(
        "---------------STEP2: Separating Non-tau from Tau -------------------"
    )
    # 1) Remove NA cells
    dat = dat.dropna()

    predicted1_slide = dat.copy()

    # 2) Dropping extra info features
    X_unlabelled = dat.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"]
    )
    # 3) Predictions
    screening_model.predict(X_unlabelled)
    predicted1_slide["Class"] = screening_model.prediction
    print(predicted1_slide["Class"].value_counts())

    # Classifier 2: tau hallmark classification
    print(
        "---------------STEP3: Tau hallmark classification -------------------"
    )
    # Select out 'tau' portion only (ignoring non-tau & ambiguous cells )
    tau_portion = predicted1_slide[predicted1_slide["Class"] == "Tau"]
    if tau_portion.shape[0] == 0:
        print("There is no tau on this slide!")
        faulty_file.append(dat["Image"][0] + " No tau on the slide")
        continue
        
    # Split BG into STR and GP & STN
    
    tau_portion_STR = tau_portion[tau_portion['Parent']=='STR']
    print('Tau on STR: ', tau_portion_STR.shape[0])
    
    if tau_portion_STR.shape[0] == 0:
        print("THERE IS NO TAU ON THIS SLIDE")
        faulty_file.append(dat["Image"][0] + " no tau on the slide")
        continue
    
    tau_portion_STN_GP = tau_portion[(tau_portion['Parent']=='STN')|(tau_portion['Parent']=='GP')]
    print('Tau on STN & GP: ', tau_portion_STN_GP.shape[0])
    
    if tau_portion_STN_GP.shape[0] == 0:
        print("THERE IS NO TAU ON THIS SLIDE")
        faulty_file.append(dat["Image"][0] + " no tau on the slide")
        continue
    
    # STR prediction
    tau_portion_STR_X = tau_portion_STR.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"]
    )
    predicted2_slide_STR = tau_portion_STR.copy()


    # 1) Get class probability predictions for 'test' data
    str_model.predict(tau_portion_STR_X)

    predicted2_slide_STR["Class"] = str_model.prediction
    print('STR predicted slide shape: ',predicted2_slide_STR["Class"].value_counts())
    
    # GP&STN 
    tau_portion_STN_GP_X = tau_portion_STN_GP.drop(
        columns=["Image",
                 "Name",
                 "Class",
                 "Parent",
                 "ROI",
                 "Centroid_X",
                 "Centroid_Y"]
    )
    predicted2_slide_STN_GP = tau_portion_STN_GP.copy()


    # 1) Get class probability predictions for 'test' data
    stn_gp_model.predict(tau_portion_STN_GP_X)

    predicted2_slide_STN_GP["Class"] = stn_gp_model.prediction
    print('STN_GP predicted slide shape: ',predicted2_slide_STN_GP["Class"].value_counts())
    
    print("---------------STEP4: Data extraction & export -------------------")
# 1) Combining predicted cells & excluded cells (prior to prediction)
    
    #get non-tau portion
    non_tau_portion = predicted1_slide[predicted1_slide["Class"] != "Tau"]
    
    #put everything together: nontau, tau in STR, GP & STN
    total_pred = pd.concat([non_tau_portion,
                            predicted2_slide_STR,
                            predicted2_slide_STN_GP])
    
    print("No loss of cells? ", predicted1_slide.shape[0] == total_pred.shape[0])

    output_visualise = total_pred[["Image",
                                   "Name",
                                   "Parent",
                                   "Class",
                                   "Centroid_X",
                                   "Centroid_Y",
                                   "Area µm^2"]]
    path_ = (prediction_path +
             output_visualise.iloc[0, 0] +
             "_predictions.txt")
    output_visualise.to_csv(path_, sep="\t", index=False)

    print("Exported prediction of : ", dat_file)
    print("---------------------------------------------------")
print("Well done, no error!")
# Out:
# FILE 703488.svs Detections.txt Number:  1 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 703488.svs Detections.txt
# Data shape is: (127406, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    80218
# Tau        47188
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  7782
# Tau on STN & GP:  39406
# STR predicted slide shape:  Others       5890
# CB           1505
# TA            213
# Ambiguous     167
# NFT             7
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       35646
# CB            3457
# Ambiguous      236
# NFT             67
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  703488.svs Detections.txt
# ---------------------------------------------------
# FILE 721708.svs Detections.txt Number:  2 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 721708.svs Detections.txt
# Data shape is: (47191, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    40514
# Tau         6677
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  881
# Tau on STN & GP:  5796
# STR predicted slide shape:  Others       781
# CB            79
# Ambiguous     12
# NFT            8
# TA             1
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       5308
# CB            392
# NFT            54
# Ambiguous      42
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721708.svs Detections.txt
# ---------------------------------------------------
# FILE 721866.svs Detections.txt Number:  3 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 721866.svs Detections.txt
# Data shape is: (35358, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    32758
# Tau         2600
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  306
# Tau on STN & GP:  2294
# STR predicted slide shape:  Others       253
# CB            50
# TA             2
# Ambiguous      1
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       2058
# CB            190
# Ambiguous      23
# NFT            23
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  721866.svs Detections.txt
# ---------------------------------------------------
# FILE 722594.svs Detections.txt Number:  4 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 722594.svs Detections.txt
# Data shape is: (155391, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        142930
# Non_tau     12461
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  41249
# Tau on STN & GP:  101681
# STR predicted slide shape:  Others       38988
# CB            1404
# TA             577
# Ambiguous      254
# NFT             26
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       99724
# CB            1700
# Ambiguous      196
# NFT             61
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  722594.svs Detections.txt
# ---------------------------------------------------
# FILE 747131.svs Detections.txt Number:  5 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747131.svs Detections.txt
# Data shape is: (30000, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    20776
# Tau         9224
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  773
# Tau on STN & GP:  8451
# STR predicted slide shape:  Others       737
# CB            24
# NFT            6
# Ambiguous      5
# TA             1
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       8001
# CB            319
# NFT            72
# Ambiguous      59
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747131.svs Detections.txt
# ---------------------------------------------------
# FILE 747293.svs Detections.txt Number:  6 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747293.svs Detections.txt
# Data shape is: (54432, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    51142
# Tau         3290
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  394
# Tau on STN & GP:  2896
# STR predicted slide shape:  Others       341
# CB            37
# Ambiguous     10
# NFT            3
# TA             3
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       2293
# CB            504
# NFT            58
# Ambiguous      41
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747293.svs Detections.txt
# ---------------------------------------------------
# FILE 747295.svs Detections.txt Number:  7 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747295.svs Detections.txt
# Data shape is: (45534, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    24424
# Tau        21110
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3244
# Tau on STN & GP:  17866
# STR predicted slide shape:  Others       3167
# CB             39
# TA             25
# Ambiguous      13
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       17653
# CB             179
# Ambiguous       25
# NFT              9
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747295.svs Detections.txt
# ---------------------------------------------------
# FILE 747296.svs Detections.txt Number:  8 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747296.svs Detections.txt
# Data shape is: (27264, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    13952
# Tau        13312
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3402
# Tau on STN & GP:  9910
# STR predicted slide shape:  Others       3014
# CB            323
# Ambiguous      47
# NFT            13
# TA              5
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       9406
# CB            385
# NFT            77
# Ambiguous      42
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747296.svs Detections.txt
# ---------------------------------------------------
# FILE 747297.svs Detections.txt Number:  9 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747297.svs Detections.txt
# Data shape is: (45737, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    36591
# Tau         9146
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3272
# Tau on STN & GP:  5874
# STR predicted slide shape:  Others       2656
# CB            512
# Ambiguous      55
# NFT            31
# TA             18
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       5287
# CB            487
# NFT            62
# Ambiguous      38
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747297.svs Detections.txt
# ---------------------------------------------------
# FILE 747299.svs Detections.txt Number:  10 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747299.svs Detections.txt
# Data shape is: (47533, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    29115
# Tau        18418
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  6780
# Tau on STN & GP:  11638
# STR predicted slide shape:  Others       6128
# CB            438
# TA            120
# Ambiguous      71
# NFT            23
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       10888
# CB             662
# Ambiguous       57
# NFT             31
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747299.svs Detections.txt
# ---------------------------------------------------
# FILE 747301.svs Detections.txt Number:  11 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747301.svs Detections.txt
# Data shape is: (25535, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    15605
# Tau         9930
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  2516
# Tau on STN & GP:  7414
# STR predicted slide shape:  Others       1941
# CB            461
# Ambiguous      61
# NFT            28
# TA             25
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       6467
# CB            872
# Ambiguous      56
# NFT            19
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747301.svs Detections.txt
# ---------------------------------------------------
# FILE 747303.svs Detections.txt Number:  12 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747303.svs Detections.txt
# Data shape is: (4605, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        3553
# Non_tau    1052
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  688
# Tau on STN & GP:  2865
# STR predicted slide shape:  Others       655
# CB            21
# Ambiguous      8
# TA             4
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       2763
# CB             87
# Ambiguous      10
# NFT             5
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747303.svs Detections.txt
# ---------------------------------------------------
# FILE 747309.svs Detections.txt Number:  13 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747309.svs Detections.txt
# Data shape is: (59368, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        30105
# Non_tau    29263
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  10963
# Tau on STN & GP:  19142
# STR predicted slide shape:  Others       9657
# CB            845
# TA            308
# Ambiguous     139
# NFT            14
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       18101
# CB             939
# Ambiguous       81
# NFT             21
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747309.svs Detections.txt
# ---------------------------------------------------
# FILE 747370.svs Detections.txt Number:  14 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747370.svs Detections.txt
# Data shape is: (46246, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    42370
# Tau         3876
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  498
# Tau on STN & GP:  3378
# STR predicted slide shape:  Others       471
# CB            13
# Ambiguous      9
# NFT            5
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       3063
# CB            239
# NFT            40
# Ambiguous      36
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747370.svs Detections.txt
# ---------------------------------------------------
# FILE 747814.svs Detections.txt Number:  15 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747814.svs Detections.txt
# Data shape is: (13819, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        11626
# Non_tau     2190
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  5325
# Tau on STN & GP:  6301
# STR predicted slide shape:  Others       4784
# TA            226
# CB            221
# Ambiguous      81
# NFT            13
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       5874
# CB            293
# NFT            97
# Ambiguous      37
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747814.svs Detections.txt
# ---------------------------------------------------
# FILE 747815.svs Detections.txt Number:  16 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747815.svs Detections.txt
# Data shape is: (37205, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    20678
# Tau        16527
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  6821
# Tau on STN & GP:  9706
# STR predicted slide shape:  Others       6300
# CB            304
# TA            113
# Ambiguous      92
# NFT            12
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       9179
# CB            423
# Ambiguous      80
# NFT            24
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747815.svs Detections.txt
# ---------------------------------------------------
# FILE 747818.svs Detections.txt Number:  17 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747818.svs Detections.txt
# Data shape is: (73515, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    42144
# Tau        31371
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  4935
# Tau on STN & GP:  26436
# STR predicted slide shape:  Others       4124
# CB            692
# Ambiguous      68
# TA             36
# NFT            15
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       25034
# CB            1244
# Ambiguous       96
# NFT             62
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747818.svs Detections.txt
# ---------------------------------------------------
# FILE 747821.svs Detections.txt Number:  18 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747821.svs Detections.txt
# Data shape is: (60312, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Tau        30499
# Non_tau    29813
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  5347
# Tau on STN & GP:  25152
# STR predicted slide shape:  Others       4995
# CB            167
# TA            121
# Ambiguous      51
# NFT            13
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       24079
# CB             920
# Ambiguous       85
# NFT             68
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747821.svs Detections.txt
# ---------------------------------------------------
# FILE 747822.svs Detections.txt Number:  19 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747822.svs Detections.txt
# Data shape is: (101222, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    87449
# Tau        13773
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3583
# Tau on STN & GP:  10190
# STR predicted slide shape:  Others       2670
# CB            788
# Ambiguous      72
# TA             38
# NFT            15
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       8695
# CB           1300
# NFT           112
# Ambiguous      83
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747822.svs Detections.txt
# ---------------------------------------------------
# FILE 747826.svs Detections.txt Number:  20 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747826.svs Detections.txt
# Data shape is: (83840, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    74765
# Tau         9075
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3053
# Tau on STN & GP:  6022
# STR predicted slide shape:  Others       2672
# CB            270
# TA             49
# Ambiguous      47
# NFT            15
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       5841
# CB            160
# Ambiguous      14
# NFT             7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747826.svs Detections.txt
# ---------------------------------------------------
# FILE 747827.svs Detections.txt Number:  21 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747827.svs Detections.txt
# Data shape is: (23527, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    21689
# Tau         1838
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  406
# Tau on STN & GP:  1432
# STR predicted slide shape:  Others       387
# CB            16
# Ambiguous      2
# NFT            1
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       1369
# CB             58
# Ambiguous       3
# NFT             2
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747827.svs Detections.txt
# ---------------------------------------------------
# FILE 747857.svs Detections.txt Number:  22 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747857.svs Detections.txt
# Data shape is: (42710, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    41139
# Tau         1571
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  726
# Tau on STN & GP:  845
# STR predicted slide shape:  Others       568
# CB           129
# Ambiguous     17
# NFT            7
# TA             5
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       782
# CB            46
# NFT           10
# Ambiguous      7
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747857.svs Detections.txt
# ---------------------------------------------------
# FILE 747868.svs Detections.txt Number:  23 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747868.svs Detections.txt
# Data shape is: (9379, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    5750
# Tau        3629
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  993
# Tau on STN & GP:  2636
# STR predicted slide shape:  Others       968
# CB            11
# NFT            7
# Ambiguous      6
# TA             1
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       2490
# CB            103
# NFT            31
# Ambiguous      12
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747868.svs Detections.txt
# ---------------------------------------------------
# FILE 747870.svs Detections.txt Number:  24 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747870.svs Detections.txt
# Data shape is: (82129, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    76684
# Tau         5445
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  225
# Tau on STN & GP:  5220
# STR predicted slide shape:  Others       207
# CB            16
# Ambiguous      2
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       4486
# CB            641
# Ambiguous      58
# NFT            35
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747870.svs Detections.txt
# ---------------------------------------------------
# FILE 747872.svs Detections.txt Number:  25 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 747872.svs Detections.txt
# Data shape is: (93660, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    77734
# Tau        15926
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  903
# Tau on STN & GP:  15023
# STR predicted slide shape:  Others       835
# CB            40
# Ambiguous     10
# TA             9
# NFT            9
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       14031
# CB             862
# Ambiguous       82
# NFT             48
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  747872.svs Detections.txt
# ---------------------------------------------------
# FILE 771914.svs Detections.txt Number:  26 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 771914.svs Detections.txt
# Data shape is: (16948, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    8631
# Tau        8317
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  3358
# Tau on STN & GP:  4959
# STR predicted slide shape:  Others       3083
# CB            176
# TA             42
# Ambiguous      39
# NFT            18
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       4467
# CB            427
# Ambiguous      44
# NFT            21
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  771914.svs Detections.txt
# ---------------------------------------------------
# FILE 772011.svs Detections.txt Number:  27 / 27
# ---------------STEP1: Read in data file -------------------
# {'GP', 'STN', 'STR'}
# Read in data file: 772011.svs Detections.txt
# Data shape is: (108026, 61)
# ---------------STEP2: Separating Non-tau from Tau -------------------
# Non_tau    75347
# Tau        32679
# Name: Class, dtype: int64
# ---------------STEP3: Tau hallmark classification -------------------
# Tau on STR:  6404
# Tau on STN & GP:  26275
# STR predicted slide shape:  Others       5918
# CB            389
# Ambiguous      65
# TA             25
# NFT             7
# Name: Class, dtype: int64
# STN_GP predicted slide shape:  Others       24908
# CB            1187
# Ambiguous      145
# NFT             35
# Name: Class, dtype: int64
# ---------------STEP4: Data extraction & export -------------------
# No loss of cells?  True
# Exported prediction of :  772011.svs Detections.txt
# ---------------------------------------------------
# Well done, no error!
